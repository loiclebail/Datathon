# %% [markdown]
# <a href="https://colab.research.google.com/github/loiclebail/Datathon/blob/main/Colab_Datathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_excel('https://iea.blob.core.windows.net/assets/a5142e9d-bcc5-4dfe-a950-3eac2f364b0c/WorldEnergyBalancesHighlights2021.xlsx', sheet_name = 'TimeSeries_1971-2020',skiprows=1)

# %%
df.shape
# Out:
# (6161, 56)

# %%
df.Country.unique().tolist()
# Out:
# ['Australia',
#  'Austria',
#  'Belgium',
#  'Canada',
#  'Chile',
#  'Colombia',
#  'Czech Republic',
#  'Denmark',
#  'Estonia',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Hungary',
#  'Iceland',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Korea',
#  'Latvia',
#  'Lithuania',
#  'Luxembourg',
#  'Mexico',
#  'Netherlands',
#  'New Zealand',
#  'Norway',
#  'Poland',
#  'Portugal',
#  'Slovak Republic',
#  'Slovenia',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Turkey',
#  'United Kingdom',
#  'United States',
#  'OECD Total',
#  'Brazil',
#  "People's Republic of China",
#  'India',
#  'Indonesia',
#  'Morocco',
#  'Singapore',
#  'South Africa',
#  'Thailand',
#  'Non-OECD Total',
#  'Africa',
#  'Non-OECD Americas',
#  'Non-OECD Asia (including China)',
#  'Non-OECD Europe and Eurasia',
#  'Middle East',
#  'IEA Total',
#  'IEA and Accession/Association countries',
#  'World']

# %%
condition = df.Country.str.contains("Austria|Belgium|Czech Republic|Denmark|Estonia|Finland|France|Germany|Greece|Spain|Estonia|Hungary|Ireland|Latvia|Lithuania|Luxembourg|Netherlands|Poland|Portugal|Italy|Slovak Republic|Slovenia|Sweden")

# %%
df_ue = df[condition]

# %%
df_ue.Country.value_counts()
# Out:
# Austria            112
# Belgium            112
# Spain              112
# Slovenia           112
# Slovak Republic    112
# Portugal           112
# Poland             112
# Netherlands        112
# Luxembourg         112
# Lithuania          112
# Latvia             112
# Italy              112
# Ireland            112
# Hungary            112
# Greece             112
# Germany            112
# France             112
# Finland            112
# Estonia            112
# Denmark            112
# Czech Republic     112
# Sweden             112
# Name: Country, dtype: int64

# %%
# Pays de l'UE non présents dans le dataset : Bulgarie,Chypre,Croatie,Malte,Roumanie

# %%
df_ue.shape
# Out:
# (2464, 56)

# %%
df_ue.drop(columns=[1971,
 1972,
 1973,
 1974,
 1975,
 1976,
 1977,
 1978,
 1979,
 1980,
 1981,
 1982,
 1983,
 1984,
 1985,
 1986,
 1987,
 1988,
 1989,
 1990,
 1991,
 1992,
 1993,
 1994,
 1995,
 1996,
 1997,
 1998,
 1999,],axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_ue.columns.tolist()
# Out:
# ['Country',
#  'Product',
#  'Flow',
#  'NoCountry',
#  'NoProduct',
#  'NoFlow',
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  '2020 Provisional']

# %%
df_ue.head()
# Out:
#      Country                   Product                                   Flow  \
# 108  Austria  Coal, peat and oil shale                        Production (PJ)
# 109  Austria  Coal, peat and oil shale                           Imports (PJ)
# 110  Austria  Coal, peat and oil shale                           Exports (PJ)
# 111  Austria  Coal, peat and oil shale               Total energy supply (PJ)
# 112  Austria  Coal, peat and oil shale  Electricity, CHP and heat plants (PJ)
#
#        NoCountry                     NoProduct  \
# 108  02. Austria  01. Coal, peat and oil shale
# 109  02. Austria  01. Coal, peat and oil shale
# 110  02. Austria  01. Coal, peat and oil shale
# 111  02. Austria  01. Coal, peat and oil shale
# 112  02. Austria  01. Coal, peat and oil shale
#
#                                         NoFlow        1971        1972  \
# 108                        01. Production (PJ)   43.483929   44.124526
# ...

# %%
df_ue.drop(columns=["NoCountry","NoProduct","NoFlow"],axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_ue.melt(id_vars=['Country','Product','Flow'], value_vars=test_col)
# Out:
#        Country                   Product  \
# 0      Austria  Coal, peat and oil shale
# 1      Austria  Coal, peat and oil shale
# 2      Austria  Coal, peat and oil shale
# 3      Austria  Coal, peat and oil shale
# 4      Austria  Coal, peat and oil shale
# ...        ...                       ...
# 51739    Spain                     Total
# 51740   Sweden              Fossil fuels
# 51741   Sweden                   Nuclear
# 51742   Sweden         Renewable sources
# 51743   Sweden                     Total
#
#                                         Flow          variable       value
# 0                            Production (PJ)              2000   12.249003
# 1                               Imports (PJ)              2000  128.342515
# 2                               Exports (PJ)              2000   -1.838717
# 3                   Total energy supply (PJ)              2000  150.743812
# 4      Electricity, CHP and heat plants (PJ)              2000   -59.46548
# ...

# %%
df_ue.to_csv("/content/drive/MyDrive/Data/Datathon/dataset_2000_2020_UE.csv",sep=",",index=False)

# %%
df_ue.isna().sum()
# Out:
# Country             0
# Product             0
# Flow                0
# 2000                0
# 2001                0
# 2002                0
# 2003                0
# 2004                0
# 2005                0
# 2006                0
# 2007                0
# 2008                0
# 2009                0
# 2010                0
# 2011                0
# 2012                0
# 2013                0
# 2014                0
# 2015                0
# 2016                0
# 2017                0
# 2018                0
# 2019                0
# 2020 Provisional    0
# dtype: int64

# %%
df_ue.Product.unique()
# Out:
# array(['Coal, peat and oil shale', 'Crude, NGL and feedstocks',
#        'Oil products', 'Natural gas', 'Nuclear', 'Renewables and waste',
#        'Electricity', 'Heat', 'Total', 'Fossil fuels',
#        'Renewable sources'], dtype=object)

# %%
df_ue.head()
# Out:
#      Country                   Product                                   Flow  \
# 108  Austria  Coal, peat and oil shale                        Production (PJ)
# 109  Austria  Coal, peat and oil shale                           Imports (PJ)
# 110  Austria  Coal, peat and oil shale                           Exports (PJ)
# 111  Austria  Coal, peat and oil shale               Total energy supply (PJ)
# 112  Austria  Coal, peat and oil shale  Electricity, CHP and heat plants (PJ)
#
#            2000        2001        2002        2003        2004        2005  \
# 108   12.249003   11.851721   13.874641   11.321442      2.3118    0.008801
# 109  128.342515  140.927847  147.322414  148.575628  166.312273  169.415801
# 110   -1.838717   -1.395523    -1.01666   -1.822853    -2.20093   -0.640074
# 111  150.743812  155.947209  159.451159  169.568519  166.885429  168.443618
# 112   -59.46548  -72.580485  -69.898325  -83.079066  -83.997809   -79.37253
#
# ...

# %%
df1 = pd.read_csv("/content/drive/MyDrive/Data/Datathon/PIB_UE_27.csv",sep=",")

# %%
df1.head()
# Out:
#   LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY  TIME       Value Flag Codes
# 0      AUT       GDP     TOT  MLN_USD         A  2006  311414.930        NaN
# 1      AUT       GDP     TOT  MLN_USD         A  2007  327096.286        NaN
# 2      AUT       GDP     TOT  MLN_USD         A  2008  343812.976        NaN
# 3      AUT       GDP     TOT  MLN_USD         A  2009  341392.998        NaN
# 4      AUT       GDP     TOT  MLN_USD         A  2010  351341.770        NaN

# %%
df1.drop(columns=["INDICATOR","SUBJECT","MEASURE","FREQUENCY","Flag Codes"],axis=1,inplace=True)

# %%
df1
# Out:
#       LOCATION  TIME         Value
# 0          AUT  2006  3.114149e+05
# 1          AUT  2007  3.270963e+05
# 2          AUT  2008  3.438130e+05
# 3          AUT  2009  3.413930e+05
# 4          AUT  2010  3.513418e+05
# ..         ...   ...           ...
# 395  EU27_2020  2017  1.904217e+07
# 396  EU27_2020  2018  1.995212e+07
# 397  EU27_2020  2019  2.060442e+07
# 398  EU27_2020  2020  2.005795e+07
# 399  EU27_2020  2021  2.189143e+07
#
# [400 rows x 3 columns]

# %%
dico={"AUT":"Austria","POL":"Poland","LTU":"Lithuania","LVA":"Latvia","SVN":"Slovenia","EST":"Estonia",
      "SWE":"Sweden","ESP":"Spain","SVK":"Slovak Republic","PRT":"Portugal","NLD":"Netherlands","BEL":"Belgium",
      "LUX":"Luxembourg","ITA":"Italy","IRL":"Ireland","HUN":"Hungary","GRC":"Greece","DEU":"Germany","FRA":"France","FIN":"Finland",
      "DNK":"Denmark","CZE":"Czech Republic"}

# %%
df_PIB = df1.replace(dico)

# %%
len(df_PIB.LOCATION.unique().tolist())
# Out:
# 25

# %%
len(df_ue.Country.unique().tolist())
# Out:
# 22

# %%
df_PIB.LOCATION.value_counts()
# Out:
# Austria            16
# Poland             16
# EA19               16
# Lithuania          16
# Latvia             16
# OECD               16
# Slovenia           16
# Estonia            16
# Sweden             16
# Spain              16
# Slovak Republic    16
# Portugal           16
# Netherlands        16
# Belgium            16
# Luxembourg         16
# Italy              16
# Ireland            16
# Hungary            16
# Greece             16
# Germany            16
# France             16
# Finland            16
# Denmark            16
# Czech Republic     16
# EU27_2020          16
# Name: LOCATION, dtype: int64

# %%
condition = df_PIB.LOCATION.str.contains("EU27_2020") == False

# %%
df_PIB_final = df_PIB[condition]

# %%
df_PIB = pd.read_csv("/content/drive/MyDrive/Data/Datathon/dataset_pib_ue",sep=",")

# %%
df_PIB.head()
# Out:
#   LOCATION  TIME       Value
# 0  Austria  2006  311414.930
# 1  Austria  2007  327096.286
# 2  Austria  2008  343812.976
# 3  Austria  2009  341392.998
# 4  Austria  2010  351341.770

# %%
df_PIB.to_csv("/content/drive/MyDrive/Data/Datathon/dataset_pib_ue.csv",sep=",",index=False)
